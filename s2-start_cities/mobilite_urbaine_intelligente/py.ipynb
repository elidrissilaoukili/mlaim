# %%
import traci
import time

BUS_TYPE = "bus"
THRESHOLD_CARS = 10

sumoCmd = ["sumo-gui", "-c", "region.sumocfg", "--remote-port", "8813"]
traci.start(sumoCmd)
print("Agent connecté à SUMO.")

try:
    for step in range(500):
        traci.simulationStep()
        veh_count = traci.edge.getLastStepVehicleNumber("edge1")
        veh_list = traci.edge.getLastStepVehicleIDs("edge1")
        bus_present = any(traci.vehicle.getTypeID(v) == BUS_TYPE for v in veh_list)

        traffic_light_id = "n2"
        current_phase = traci.trafficlight.getPhase(traffic_light_id)

        if bus_present and current_phase != 0:
            print("🚌 Bus détecté, passage au vert.")
            traci.trafficlight.setPhase(traffic_light_id, 0)
        elif veh_count > THRESHOLD_CARS and current_phase != 0:
            print(f"🚗 {veh_count} voitures détectées, passage au vert.")
            traci.trafficlight.setPhase(traffic_light_id, 0)

        time.sleep(0.05)
finally:
    traci.close()
    print("✅ Simulation terminée.")
# Out:
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14705 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14707 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14710 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14713 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14717 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14719 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14723 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14729 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14732 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14737 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14743 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14745 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14754 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14761 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14764 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14766 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14769 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14771 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14773 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14775 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14778 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14780 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14783 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14785 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14787 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14789 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14791 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14793 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14795 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14797 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14799 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14801 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14803 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14805 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14807 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14809 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14812 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14814 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14816 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14818 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14820 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14823 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14825 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14827 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14832 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14834 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14836 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14838 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14840 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14842 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14845 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14847 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14849 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14851 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14853 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14855 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14857 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14859 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14861 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14863 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 14865 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# ---------------------------------------------------------------------------
# FatalTraCIError                           Traceback (most recent call last)
# Cell In[3], line 8
#       5 THRESHOLD_CARS = 10
#       7 sumoCmd = ["sumo-gui", "-c", "region.sumocfg", "--remote-port", "8813"]
# ----> 8 traci.start(sumoCmd)
#       9 print("Agent connecté à SUMO.")
#      11 try:
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:157, in start(cmd, port, numRetries, label, verbose, traceFile, traceGetters, stdout, doSwitch)
#     154         warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#     155                        " Retrying with different port.") % (sumoPort, e))
#     156         numRetries -= 1
# --> 157 raise FatalTraCIError("Could not connect.")
#
# FatalTraCIError: Could not connect.
