# %%
a=21
b=42
c=a+b
print(f"Value is {c}")
# Out:
# Value is 63

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(0, 10, 0.1)

f = 0.3

x = np.sin(2*np.pi*f*n)

plt.plot(n, x, label="sinusoide")

plt.legend()

plt.xlabel("$n$")
plt.ylabel("$x[n]$")
plt.title("une belle sinsoide")

plt.show()

# %%
#vecteur des 
t = np.arange(0, 1, 2e-3)

# parametres
A = 2
f = 5
phi = np.pi/3

# sinusoide
x = A * np.sin(2*np.pi*f*t + phi)

# affichage
plt.plot(t, x)
plt.xlabel("t")
plt.ylabel("y(t)")
plt.show()

# %%
#vecteur des 
t = np.arange(0, 10, .05)

# parametres
A = 2
a = 0.5
f = 2
 
# sinusoide amortie
expo = np.exp(-a*t)
sinus = np.sin(2*np.pi*f*t)
y = A * expo * sinus

# affichage
plt.plot(t, y)
plt.xlabel("t")
plt.ylabel("y(t)")
plt.title("A=2, a=0.5, f=2 Hz")
plt.show()

# %%
# parametres
A, m, N = 3 , 4, 5

# Abscisses
n = np.arange(-10, 10)

# signal
n2 = (n - m) / N
z = A * np.where((n2 >= -.5) & (n2 <= .5), 1, 0)

# Affichage
plt.figure(figsize=(10, 3))
plt.stem(n, z, basefmt=" ")
plt.xticks(n)
plt.show()
