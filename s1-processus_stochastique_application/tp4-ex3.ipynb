# %%
import numpy as np; import matplotlib.pyplot as plt;
N_R=500; N_va=1000; 
X=[];
t = np.linspace(0,N_va-1,N_va)
mux=0; varx=1;
X=mux+np.sqrt(varx)*np.random.randn(N_R,N_va)
plt.figure(1);plt.plot(t,X[0,:]);plt.plot(t,X[1,:]);plt.plot(t,X[10,:]);plt.plot(t,X[11,:])
