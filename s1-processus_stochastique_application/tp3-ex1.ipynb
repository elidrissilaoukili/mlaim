# %%
import random
print("You rolled the following number",random.randint(1,6))
# Out:
# You rolled the following number 2

# %%
from random import randint
repeat_rolling = True
while repeat_rolling:
    print("You rolled the following number using the Dice : ",randint(1,6))
    print("Do you wish to roll the dice again?")
    repeat_rolling = ("y" or "yes") in input().lower()
# Out:
# You rolled the following number using the Dice :  6
# Do you wish to roll the dice again?

# %%
from random import randint
x=randint(1,6)
print(x)
if x==2 or x==5 :
    print("vous avez gagné")
else:
    print("vous avez perdu")
# Out:
# 4
# vous avez perdu

# %%
from random import randint
nb=0
for i in range(0,1000):
    x=randint(1,6)
    if x==2 or x==5 : 
        nb=nb+1
print("vous avez gagné",nb,"fois en 1000 de lancer de dé successif")
# Out:
# vous avez gagné 334 fois en 1000 de lancer de dé successif

# %%
import numpy as np; import matplotlib.pyplot as plt
N = 60; a = 1 ; b = 6 ;
X = np.random.randint(a,b+1,N) ;
plt.figure(1); plt.stem(X); plt.grid(True);
plt.title("lancer du dé")
bins=(b-a)+1; I = np.linspace(a,b,bins)
(P,J) = np.histogram(X,bins);
plt.figure(2); plt.subplot(211); plt.stem(I,P);
plt.grid(True);
plt.subplot(212); plt.hist(X, bins, density = True)
mu=np.mean(X);vv=np.var(X) ; vvv=np.std(X)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import numpy as np; import matplotlib.pyplot as plt
#       2 N = 60; a = 1 ; b = 6 ;
#       3 X = np.random.randint(a,b+1,N) ;
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import numpy as np; import matplotlib.pyplot as plt;
a = 1 ; b = 6 ;
NN=np.array([6,60,600,60000])
plt.figure(1);i=1;
for N in NN:
    X = np.random.randint(a,b+1,N) ;
    bins = (b-a)+1; I = np.linspace(a,b,bins)
    P,I1 = np.histogram(X,bins);
    plt.subplot(2,2,i)
    plt.stem(I,P); plt.grid(True);
    plt.title("lancer du dé pour n=%d "%N)
    i+=1    
X = np.random.randint(a,b+1,60) ;
plt.figure(2); plt.stem(X); plt.grid(True);
